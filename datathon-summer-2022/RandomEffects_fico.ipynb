# %%
# !pip install uszipcode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: uszipcode in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (from uszipcode) (0.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from uszipcode) (2.23.0)
# Requirement already satisfied: atomicwrites in /usr/local/lib/python3.7/dist-packages (from uszipcode) (1.4.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from uszipcode) (21.4.0)
# Requirement already satisfied: haversine>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from uszipcode) (2.6.0)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from uszipcode) (1.4.39)
# Requirement already satisfied: sqlalchemy-mate>=1.4.28.3 in /usr/local/lib/python3.7/dist-packages (from uszipcode) (1.4.28.3)
# Requirement already satisfied: pathlib-mate in /usr/local/lib/python3.7/dist-packages (from uszipcode) (1.0.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.4.0->uszipcode) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.4.0->uszipcode) (1.1.2)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.7/dist-packages (from sqlalchemy-mate>=1.4.28.3->uszipcode) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->SQLAlchemy>=1.4.0->uszipcode) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->SQLAlchemy>=1.4.0->uszipcode) (3.8.1)
# Requirement already satisfied: autopep8 in /usr/local/lib/python3.7/dist-packages (from pathlib-mate->uszipcode) (1.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pathlib-mate->uszipcode) (1.15.0)
# Requirement already satisfied: pycodestyle>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from autopep8->pathlib-mate->uszipcode) (2.8.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from autopep8->pathlib-mate->uszipcode) (0.10.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prettytable->sqlalchemy-mate>=1.4.28.3->uszipcode) (0.2.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->uszipcode) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->uszipcode) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->uszipcode) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->uszipcode) (1.24.3)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from uszipcode import SearchEngine
# import us
# Out:
# /usr/local/lib/python3.7/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from google.colab import drive
drive.mount("/drive")
# df = pd.read_csv("/drive/My Drive/dataopen/LC/Lending_Club_Accepted_2014_2018.csv", delimiter = ',')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
accepted = pd.read_csv("/drive/MyDrive/Summer_2022_Datathon/LC/Lending_Club_Accepted_2014_2018.csv", delimiter = ',') 
# rejected = pd.read_csv("/drive/MyDrive/Summer_2022_Datathon/LC/Lending_Club_Rejected_2014_2018.csv", delimiter = ',', usecols=['Application_Date', 'Zip_Code'])
# immigration_dataset = pd.read_csv('/drive/My Drive/dataopen/met-immigration.csv', usecols=['NAME', 'INTERNATIONALMIG2021','NETMIG2021','INTERNATIONALMIG2020'], encoding='unicode_escape') 
immigration_dataset = pd.read_csv( '/drive/MyDrive/Summer_2022_Datathon/Continent_data.csv',usecols=['Imm% tot pop', 'Metro N Imm', 'Round total MSA population'], delimiter = '\t', encoding='UTF-16') 
name = pd.read_csv( '/drive/MyDrive/Summer_2022_Datathon/Continent_data.csv', usecols=['Metro'],delimiter = '\t', encoding='UTF-16')                  
uszips = pd.read_csv('/drive/MyDrive/Summer_2022_Datathon/archive/uszips.csv')
# uszips = pd.read_csv('/drive/MyDrive/dataopen/uszips.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (19,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
accepted['year'] = [int(x.split('-')[1]) for x in accepted['issue_d']]
accepted['zip_code'] = [str(x)[:3] for x in accepted['zip_code']]

# %%
accepted['annual_inc']
# Out:
# 0           55000.0
# 1           65000.0
# 2           63000.0
# 3          110000.0
# 4          104433.0
#              ...
# 2029947     95000.0
# 2029948    108000.0
# 2029949    227000.0
# 2029950    110000.0
# 2029951     95000.0
# Name: annual_inc, Length: 2029952, dtype: float64

# %%
immigration_dataset=pd.concat([immigration_dataset,name], axis=1)
immigration_dataset=immigration_dataset.sort_values(by=['Imm% tot pop'], ascending=False)

# %%
accepted_pre = accepted[accepted['year'] < 2016]
accepted_post = accepted[accepted['year'] >= 2016]
accepted_pre.set_index(['issue_d'], append=True)
accepted_pre.set_index('zip_code', append=True)
accepted_post.set_index('issue_d')
# Out:
#                  id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# issue_d
# Mar-2018  130954621        NaN     5000.0       5000.0           5000.0
# Mar-2018  130964697        NaN    15000.0      15000.0          15000.0
# Mar-2018  130955326        NaN    11200.0      11200.0          11200.0
# Mar-2018  130504052        NaN    25000.0      25000.0          25000.0
# Mar-2018  130956066        NaN     3000.0       3000.0           3000.0
# ...             ...        ...        ...          ...              ...
# Oct-2016   89885898        NaN    24000.0      24000.0          24000.0
# Oct-2016   88977788        NaN    24000.0      24000.0          24000.0
# Oct-2016   88985880        NaN    40000.0      40000.0          40000.0
# Oct-2016   88224441        NaN    24000.0      24000.0          24000.0
# Oct-2016   88215728        NaN    14000.0      14000.0          14000.0
#
#                 term  int_rate  installment grade sub_grade  ...  \
# issue_d                                                      ...
# Mar-2018   36 months     20.39       186.82     D        D4  ...
# Mar-2018   36 months      9.92       483.45     B        B2  ...
# Mar-2018   60 months     30.79       367.82     G        G1  ...
# Mar-2018   60 months     21.85       688.35     D        D5  ...
# Mar-2018   36 months      7.34        93.10     A        A4  ...
# ...              ...       ...          ...   ...       ...  ...
# Oct-2016   60 months     12.79       543.50     C        C1  ...
# Oct-2016   60 months     10.49       515.74     B        B3  ...
# Oct-2016   60 months     10.49       859.56     B        B3  ...
# Oct-2016   60 months     14.49       564.56     C        C4  ...
# Oct-2016   60 months     14.49       329.33     C        C4  ...
#
#          hardship_last_payment_amount disbursement_method  \
# issue_d
# Mar-2018                          NaN                Cash
# Mar-2018                          NaN                Cash
# Mar-2018                          NaN                Cash
# Mar-2018                          NaN                Cash
# Mar-2018                          NaN                Cash
# ...                               ...                 ...
# Oct-2016                          NaN                Cash
# Oct-2016                          NaN                Cash
# Oct-2016                          NaN                Cash
# Oct-2016                          NaN                Cash
# Oct-2016                          NaN                Cash
#
#          debt_settlement_flag  debt_settlement_flag_date settlement_status  \
# issue_d
# Mar-2018                    N                        NaN               NaN
# Mar-2018                    N                        NaN               NaN
# Mar-2018                    N                        NaN               NaN
# Mar-2018                    N                        NaN               NaN
# Mar-2018                    N                        NaN               NaN
# ...                       ...                        ...               ...
# Oct-2016                    N                        NaN               NaN
# Oct-2016                    N                        NaN               NaN
# Oct-2016                    N                        NaN               NaN
# Oct-2016                    Y                   Mar-2019            ACTIVE
# Oct-2016                    N                        NaN               NaN
#
#          settlement_date settlement_amount settlement_percentage  \
# issue_d
# Mar-2018             NaN               NaN                   NaN
# Mar-2018             NaN               NaN                   NaN
# Mar-2018             NaN               NaN                   NaN
# Mar-2018             NaN               NaN                   NaN
# Mar-2018             NaN               NaN                   NaN
# ...                  ...               ...                   ...
# Oct-2016             NaN               NaN                   NaN
# Oct-2016             NaN               NaN                   NaN
# Oct-2016             NaN               NaN                   NaN
# Oct-2016        Mar-2019           10000.0                 44.82
# Oct-2016             NaN               NaN                   NaN
#
#          settlement_term  year
# issue_d
# Mar-2018             NaN  2018
# Mar-2018             NaN  2018
# Mar-2018             NaN  2018
# Mar-2018             NaN  2018
# Mar-2018             NaN  2018
# ...                  ...   ...
# Oct-2016             NaN  2016
# Oct-2016             NaN  2016
# Oct-2016             NaN  2016
# Oct-2016             1.0  2016
# Oct-2016             NaN  2016
#
# [1373228 rows x 151 columns]

# %%
generated_zips = []
zip_base = set()
for place in immigration_dataset['Metro']:
    city_names = place.split(', ')[0].split('-')
    state_name = place.split(', ')[1]
    in_state = uszips[uszips.state_id == state_name]
    city_zips = set()
    # city_zips = ''
    for city_name in city_names:
      city_zips = city_zips.union(set([str(x)[:3] for x in in_state[in_state.city == city_name].zip]))
    county_name_zips = set([str(x)[:3] for x in in_state[in_state.county_name == city_name].zip])
    zips = city_zips.union(county_name_zips)
    generated_zips.append(zips)
    zip_base = zip_base.union(zips)

immigration_dataset['zips'] = generated_zips

# %%
imm_pre = immigration_dataset
imm_post = immigration_dataset

# %%
imm_pre.head()
# Out:
#      Imm% tot pop  Metro N Imm  Round total MSA population  \
# 250      0.406993      2478853                     6091000
# 114      0.385842       766995                     1988000
# 208      0.331390        15403                       46000
# 271      0.330924      4384613                    13250000
# 433      0.314917        18320                       58000
#
#                                        Metro                  zips
# 250  Miami-Fort Lauderdale-Pompano Beach, FL       {331, 333, 330}
# 114       San Jose-Sunnyvale-Santa Clara, CA  {940, 951, 950, 943}
# 208                              Nogales, AZ                 {856}
# 271       Los Angeles-Long Beach-Anaheim, CA       {900, 928, 908}
# 433                           Eagle Pass, TX                 {788}

# %%
imm_post.head()
# Out:
#      Imm% tot pop  Metro N Imm  Round total MSA population  \
# 250      0.406993      2478853                     6091000
# 114      0.385842       766995                     1988000
# 208      0.331390        15403                       46000
# 271      0.330924      4384613                    13250000
# 433      0.314917        18320                       58000
#
#                                        Metro                  zips
# 250  Miami-Fort Lauderdale-Pompano Beach, FL       {331, 333, 330}
# 114       San Jose-Sunnyvale-Santa Clara, CA  {940, 951, 950, 943}
# 208                              Nogales, AZ                 {856}
# 271       Los Angeles-Long Beach-Anaheim, CA       {900, 928, 908}
# 433                           Eagle Pass, TX                 {788}

# %%
existing_zip_pre = set(accepted_pre.zip_code)
existing_zip_post = set(accepted_post.zip_code)

# %%
l = len(immigration_dataset)
decilep = imm_pre.iloc[int(0.1*l)]['Imm% tot pop']
decilepost = imm_post.iloc[int(0.1*l)]['Imm% tot pop']

# %%
imm_pre['Immigrant90'] = immigration_dataset['Imm% tot pop'].apply(lambda x: 1 if x >= decilep else 0)
imm_pre['Immigrant90'] = immigration_dataset['Imm% tot pop'].apply(lambda x: 1 if x >= decilepost else 0)

# %%
imm_pre = imm_pre[imm_pre['zips'].apply(lambda x: len(x.intersection(existing_zip_pre)) != 0)]
imm_post = imm_post[imm_post['zips'].apply(lambda x: len(x.intersection(existing_zip_post)) != 0)]
imm_pre.zips = imm_pre['zips'].apply(lambda x: x.intersection(existing_zip_pre))
imm_post.zips = imm_post['zips'].apply(lambda x: x.intersection(existing_zip_post))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
len(imm_pre), len(imm_post)
# Out:
# (514, 510)

# %%
zips_meanp = accepted_pre.groupby(['zip_code']).int_rate.mean()
zips_meanpo = accepted_post.groupby(['zip_code']).int_rate.mean()

# %%
ficopl = accepted_pre.groupby(['zip_code']).fico_range_low.mean()
ficopol = accepted_post.groupby(['zip_code']).fico_range_low.mean()
ficoph = accepted_pre.groupby(['zip_code']).fico_range_high.mean()
ficopoh = accepted_post.groupby(['zip_code']).fico_range_high.mean()

# %%
income_meanp = accepted_pre.groupby(['annual_inc']).int_rate.mean()
income_meanpo = accepted_post.groupby(['annual_inc']).int_rate.mean()

# %%
imm_pre.head()
# Out:
#      Imm% tot pop  Metro N Imm  Round total MSA population  \
# 250      0.406993      2478853                     6091000
# 114      0.385842       766995                     1988000
# 208      0.331390        15403                       46000
# 271      0.330924      4384613                    13250000
# 433      0.314917        18320                       58000
#
#                                        Metro                  zips  \
# 250  Miami-Fort Lauderdale-Pompano Beach, FL       {331, 333, 330}
# 114       San Jose-Sunnyvale-Santa Clara, CA  {940, 951, 950, 943}
# 208                              Nogales, AZ                 {856}
# 271       Los Angeles-Long Beach-Anaheim, CA       {900, 928, 908}
# 433                           Eagle Pass, TX                 {788}
#
#      Immigrant90
# 250            1
# 114            1
# 208            1
# 271            1
# 433            1

# %%
import statistics
imm_pre['Int'] = imm_pre['zips'].apply(lambda x: statistics.mean([zips_meanp[i] for i in x]))
imm_post['Int'] = imm_post['zips'].apply(lambda x: statistics.mean([zips_meanpo[i] for i in x]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
imm_pre['fico'] = imm_pre['zips'].apply(lambda x: statistics.mean([(ficoph[i]+ficopl[i])/2 for i in x]))
imm_post['fico'] = imm_post['zips'].apply(lambda x: statistics.mean([(ficopoh[i]+ficopol[i])/2 for i in x]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# pct_imm = []
# for place in accepted['zip_code']:
#   if place in zip_base: 
#     for i, zips in enumerate(immigration_dataset['zips']):
#       if place in zips:
#         pct_imm.append(immigration_dataset.iloc[i]['Imm% tot pop'])
#         break
#   else:
#     pct_imm.append(None)

# %%
accepted_pre.head().issue_d
# Out:
# 0    Dec-2015
# 1    Dec-2015
# 2    Dec-2015
# 3    Dec-2015
# 4    Dec-2015
# Name: issue_d, dtype: object

# %% [markdown]
# ### Research Question: How does immigration rate of a city affect interest rate?

# %%
dates = accepted_pre.index.get_level_values(0).to_list()
accepted_pre['issue_d'] = pd.Categorical(dates)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# PooledOLS and check required assumptions

# %%
pip install linearmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: linearmodels in /usr/local/lib/python3.7/dist-packages (4.25)
# Requirement already satisfied: mypy-extensions>=0.4 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (0.4.3)
# Requirement already satisfied: formulaic in /usr/local/lib/python3.7/dist-packages (from linearmodels) (0.3.4)
# Requirement already satisfied: statsmodels>=0.11 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (0.13.2)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (1.7.3)
# Requirement already satisfied: patsy in /usr/local/lib/python3.7/dist-packages (from linearmodels) (0.5.2)
# Requirement already satisfied: Cython>=0.29.21 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (0.29.30)
# Requirement already satisfied: pyhdfe>=0.1 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (0.1.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (1.21.6)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (1.3.5)
# Requirement already satisfied: property-cached>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from linearmodels) (1.6.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->linearmodels) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->linearmodels) (1.15.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11->linearmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels>=0.11->linearmodels) (3.0.9)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.7/dist-packages (from formulaic->linearmodels) (1.14.1)
# Requirement already satisfied: astor>=0.8 in /usr/local/lib/python3.7/dist-packages (from formulaic->linearmodels) (0.8.1)
# Requirement already satisfied: interface-meta<2.0.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from formulaic->linearmodels) (1.3.0)

# %%
pip install statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.13.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.2->statsmodels) (1.15.0)

# %%
accepted_pre['issue_d']
# Out:
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#             ...
# 1352670    1352670
# 1352671    1352671
# 1352672    1352672
# 1352673    1352673
# 1352674    1352674
# Name: issue_d, Length: 656724, dtype: category
# Categories (656724, int64): [0, 1, 2, 3, ..., 1352671, 1352672, 1352673, 1352674]

# %%
# Perform PooledOLS
# from linearmodels import PooledOLS
# import statsmodels.api as sm
# exog = sm.tools.tools.add_constant(np.array(zip(accepted_pre['issue_d'].to_list(), accepted_pre['pct_imm'].to_list())))
# endog = np.array(accepted_pre['int_rate'].to_list())
# mod = PooledOLS(endog, exog)
# pooledOLS_res = mod.fit(cov_type='clustered', cluster_entity=True)
# # Store values for checking homoskedasticity graphically
# fittedvals_pooled_OLS = pooledOLS_res.predict().fitted_values
# residuals_pooled_OLS = pooledOLS_res.resids

# %%
accepted_pre.set_index(['issue_d'])
accepted_pre.set_index(['zip_code'])
# Out:
#                 id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# zip_code
# 190       68407277        NaN     3600.0       3600.0           3600.0
# 577       68355089        NaN    24700.0      24700.0          24700.0
# 605       68341763        NaN    20000.0      20000.0          20000.0
# 076       66310712        NaN    35000.0      35000.0          35000.0
# 174       68476807        NaN    10400.0      10400.0          10400.0
# ...            ...        ...        ...          ...              ...
# 773        8598660        NaN    18400.0      18400.0          18400.0
# 377        9684700        NaN    22000.0      22000.0          22000.0
# 913        9604874        NaN     2000.0       2000.0           2000.0
# 458        9584776        NaN    20700.0      20700.0          20700.0
# 950        9199665        NaN    10000.0      10000.0           9975.0
#
#                 term  int_rate  installment grade sub_grade  ...  \
# zip_code                                                     ...
# 190        36 months     13.99       123.03     C        C4  ...
# 577        36 months     11.99       820.28     C        C1  ...
# 605        60 months     10.78       432.66     B        B4  ...
# 076        60 months     14.85       829.90     C        C5  ...
# 174        60 months     22.45       289.91     F        F1  ...
# ...              ...       ...          ...   ...       ...  ...
# 773        60 months     14.47       432.64     C        C2  ...
# 377        60 months     19.97       582.50     D        D5  ...
# 913        36 months      7.90        62.59     A        A4  ...
# 458        60 months     16.99       514.34     D        D1  ...
# 950        36 months     19.20       367.58     D        D3  ...
#
#          hardship_last_payment_amount disbursement_method  \
# zip_code
# 190                               NaN                Cash
# 577                               NaN                Cash
# 605                               NaN                Cash
# 076                               NaN                Cash
# 174                               NaN                Cash
# ...                               ...                 ...
# 773                               NaN                Cash
# 377                               NaN                Cash
# 913                               NaN                Cash
# 458                               NaN                Cash
# 950                               NaN                Cash
#
#          debt_settlement_flag  debt_settlement_flag_date settlement_status  \
# zip_code
# 190                         N                        NaN               NaN
# 577                         N                        NaN               NaN
# 605                         N                        NaN               NaN
# 076                         N                        NaN               NaN
# 174                         N                        NaN               NaN
# ...                       ...                        ...               ...
# 773                         N                        NaN               NaN
# 377                         N                        NaN               NaN
# 913                         N                        NaN               NaN
# 458                         N                        NaN               NaN
# 950                         N                        NaN               NaN
#
#          settlement_date settlement_amount settlement_percentage  \
# zip_code
# 190                  NaN               NaN                   NaN
# 577                  NaN               NaN                   NaN
# 605                  NaN               NaN                   NaN
# 076                  NaN               NaN                   NaN
# 174                  NaN               NaN                   NaN
# ...                  ...               ...                   ...
# 773                  NaN               NaN                   NaN
# 377                  NaN               NaN                   NaN
# 913                  NaN               NaN                   NaN
# 458                  NaN               NaN                   NaN
# 950                  NaN               NaN                   NaN
#
#          settlement_term  year
# zip_code
# 190                  NaN  2015
# 577                  NaN  2015
# 605                  NaN  2015
# 076                  NaN  2015
# 174                  NaN  2015
# ...                  ...   ...
# 773                  NaN  2014
# 377                  NaN  2014
# 913                  NaN  2014
# 458                  NaN  2014
# 950                  NaN  2014
#
# [656724 rows x 151 columns]

# %%
imm_pre.columns
# Out:
# Index(['Imm% tot pop', 'Metro N Imm', 'Round total MSA population', 'Metro',
#        'zips', 'Immigrant90', 'Int', 'fico'],
#       dtype='object')

# %%
imm_pre['zipstr'] = imm_pre.zips.apply(lambda x: list(x)[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
imm_pre['ficostr'] = imm_pre['fico'].apply(lambda x: str(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
imm_pre.head()
# Out:
#      Imm% tot pop  Metro N Imm  Round total MSA population  \
# 250      0.406993      2478853                     6091000
# 114      0.385842       766995                     1988000
# 208      0.331390        15403                       46000
# 271      0.330924      4384613                    13250000
# 433      0.314917        18320                       58000
#
#                                        Metro                  zips  \
# 250  Miami-Fort Lauderdale-Pompano Beach, FL       {331, 330, 333}
# 114       San Jose-Sunnyvale-Santa Clara, CA  {950, 951, 940, 943}
# 208                              Nogales, AZ                 {856}
# 271       Los Angeles-Long Beach-Anaheim, CA       {908, 900, 928}
# 433                           Eagle Pass, TX                 {788}
#
#      Immigrant90        Int        fico zipstr            ficostr
# 250            1  13.069119  693.755485    331  693.7554853928906
# 114            1  12.646128  696.811703    950  696.8117033860568
# 208            1  12.960563  696.554974    856  696.5549738219895
# 271            1  12.921089  694.694527    908  694.6945271654282
# 433            1  13.127181  696.669604    788   696.669603524229

# %%
import statsmodels.api as sm

# FE und RE model
from linearmodels import PanelOLS
from linearmodels import RandomEffects
imm_pre = imm_pre.set_index(['zipstr', 'fico'])
exog = sm.tools.tools.add_constant(imm_pre['Imm% tot pop'])
endog = imm_pre['Int']
# random effects model
model_re = RandomEffects(endog, exog) 
re_res = model_re.fit() 
# fixed effects model
model_fe = PanelOLS(endog, exog, entity_effects = True) 
fe_res = model_fe.fit() 
#print results
print(re_res)
print(fe_res)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                    Int   R-squared:                        0.9370
# Estimator:              RandomEffects   R-squared (Between):             -0.0016
# No. Observations:                 514   R-squared (Within):               0.0078
# Date:                Sun, Jul 24 2022   R-squared (Overall):             -0.0015
# Time:                        01:04:44   Log-likelihood                    547.92
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      7609.2
# Entities:                         378   P-value                           0.0000
# Avg Obs:                       1.3598   Distribution:                   F(1,512)
# Min Obs:                       1.0000
# Max Obs:                       5.0000   F-statistic (robust):             0.4433
#                                         P-value                           0.5058
# Time periods:                     410   Distribution:                   F(1,512)
# Avg Obs:                       1.2537
# Min Obs:                       1.0000
# Max Obs:                       5.0000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            13.112     0.0347     377.58     0.0000      13.044      13.180
# Imm% tot pop     0.0971     0.1458     0.6658     0.5058     -0.1894      0.3836
# ================================================================================
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    Int   R-squared:                        0.0096
# Estimator:                   PanelOLS   R-squared (Between):             -0.0032
# No. Observations:                 514   R-squared (Within):               0.0096
# Date:                Sun, Jul 24 2022   R-squared (Overall):             -0.0023
# Time:                        01:04:44   Log-likelihood                    891.59
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.3114
# Entities:                         378   P-value                           0.2542
# Avg Obs:                       1.3598   Distribution:                   F(1,135)
# Min Obs:                       1.0000
# Max Obs:                       5.0000   F-statistic (robust):             1.3114
#                                         P-value                           0.2542
# Time periods:                     410   Distribution:                   F(1,135)
# Avg Obs:                       1.2537
# Min Obs:                       1.0000
# Max Obs:                       5.0000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            13.115     0.0135     971.09     0.0000      13.089      13.142
# Imm% tot pop     0.1731     0.1512     1.1452     0.2542     -0.1258      0.4720
# ================================================================================
#
# F-test for Poolability: 69.361
# P-value: 0.0000
# Distribution: F(377,135)
#
# Included effects: Entity
